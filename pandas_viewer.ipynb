# %% [markdown]
# # Pandas PostgreSQL Viewer
#
# This notebook uses Pandas to view the PostgreSQL analytics tables after ETL execution.
#
# Tables viewed:
# - `customer_analytics`
# - `order_analytics`

# %%
import pandas as pd
import psycopg2
from config.loader import get

def get_db_connection():
    return psycopg2.connect(
        host=get('database.host'),
        port=get('database.port'),
        dbname=get('database.name'),
        user=get('database.user'),
        password=get('database.password')
    )

def query_to_dataframe(query):
    conn = get_db_connection()
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

# %%
# SQL Queries
customer_query = """
SELECT * FROM customer_analytics LIMIT 10;
"""

order_query = """
SELECT * FROM order_analytics LIMIT 10;
"""

customer_count_query = """
SELECT COUNT(*) as total_customers FROM customer_analytics;
"""

order_count_query = """
SELECT COUNT(*) as total_orders FROM order_analytics;
"""

# %%
# Execute queries
customer_df = query_to_dataframe(customer_query)
order_df = query_to_dataframe(order_query)
customer_count = query_to_dataframe(customer_count_query)
order_count = query_to_dataframe(order_count_query)
# Out:
# /tmp/ipykernel_114280/3784309146.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# /tmp/ipykernel_114280/3784309146.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# /tmp/ipykernel_114280/3784309146.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
# Display results
print("Customer Analytics Sample:")
display(customer_df)
print(f"\nTotal Customers: {customer_count.iloc[0,0]}")

print("\nOrder Analytics Sample:")
display(order_df)
print(f"\nTotal Orders: {order_count.iloc[0,0]}")
# Out:
# Customer Analytics Sample:
#    id  customer_id         full_name                             email  \
# 0   4            4       James Davis       james.davis@x.dummyjson.com
# 1   5            5       Emma Miller       emma.miller@x.dummyjson.com
# 2   6            6     Olivia Wilson     olivia.wilson@x.dummyjson.com
# 3   7            7   Alexander Jones   alexander.jones@x.dummyjson.com
# 4   8            8        Ava Taylor        ava.taylor@x.dummyjson.com
# 5  76           76  Madeline Simpson  madeline.simpson@x.dummyjson.com
# 6  77           77   Jonathan Pierce   jonathan.pierce@x.dummyjson.com
# 7  78           78     Eleanor Tyler     eleanor.tyler@x.dummyjson.com
# 8  79           79    Isaac Lawrence    isaac.lawrence@x.dummyjson.com
# 9  80           80     Hazel Gardner     hazel.gardner@x.dummyjson.com
#
#           city  customer_tenure_days  total_orders  total_spent  \
# 0       Mumbai                   680           100     95237.28
# ...
